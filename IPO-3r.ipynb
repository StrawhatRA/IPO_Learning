# %%
from pathlib import Path
import pandas as pd
from datetime import timedelta
import datetime
import requests
import yfinance as yf
import numpy as np
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.linear_model import LogisticRegression
import glob
import seaborn as sns
import matplotlib.pyplot as plt
#import torch
#import torch.nn as nn
#import torch.optim as optim
#from torch.nn import functional as F
#from torch.utils.data import Dataset, DataLoader
#from xgboost import XGBClassifier
from sklearn import metrics
from imblearn.over_sampling import RandomOverSampler
from collections import Counter
from sklearn.metrics import plot_confusion_matrix

# %%
#read csv data from IPO Scoop into a dataframe and set the company Symbol as the index
#other columns include industry type, amount of shares in millions, initial offer price, closing on the first day
#current price and returns, and then dropping the 1st day close column
ipo_csv = pd.read_csv('IpoScoop2018+.csv')
#filtered_ipo=ipo_csv.drop(columns=["1st Day Close"])
ipo_csv.set_index('Symbol',inplace=True)

filtered_ipo = ipo_csv
filtered_ipo
# Out:
#                                  Company     Industry Offer Date  \
# Symbol
# BLTE                    Belite Bio, Inc.  Health Care  4/29/2022
# HLVX                      HilleVax, Inc.  Health Care  4/29/2022
# OST     Ostin Technology Group Co., Ltd.  Industrials  4/27/2022
# TNON                 Tenon Medical, Inc.  Health Care  4/27/2022
# JCSE       JE Cleantech Holdings Limited  Industrials  4/22/2022
# ...                                  ...          ...        ...
# TLRY                              Tilray  Health Care  7/19/2018
# CCB                    Coastal Financial   Financials  7/18/2018
# CRNX           Crinetics Pharmaceuticals  Health Care  7/18/2018
# RUBY                 Rubius Therapeutics  Health Care  7/18/2018
# DOMO                                Domo   Technology  6/29/2018
#
#         Shares (millions) Offer Price 1st Day Close Current Price   Return
# Symbol
# BLTE                  6.0       $6.00        $10.59        $10.59   76.50%
# HLVX                 11.8      $17.00        $19.09        $19.09   12.29%
# OST                   3.4       $4.00        $39.66         $3.70   -7.50%
# TNON                  3.2       $5.00        $22.50        $21.61  332.20%
# JCSE                  3.8       $4.00        $19.00         $4.35    8.75%
# ...                   ...         ...           ...           ...      ...
# TLRY                  9.0      $17.00        $22.39        $46.56  173.88%
# CCB                   2.9      $14.50        $16.40        $15.47    6.69%
# CRNX                  6.0      $17.00        $24.51        $25.00   47.06%
# RUBY                 10.5      $23.00        $24.25        $15.73  -31.61%
# DOMO                  9.2      $21.00        $27.30        $27.32   30.10%
#
# [886 rows x 8 columns]

# %%
#visualization of different industries
sector_count = filtered_ipo["Industry"].value_counts()
sector_count.plot(kind="pie")
# Out:
# <AxesSubplot:ylabel='Industry'>

# %%
# drop tickers that were discontinued
filtered_ipo["Offer Date"]=pd.to_datetime(filtered_ipo["Offer Date"], infer_datetime_format=True)
filter_ipo = filtered_ipo.drop(['MTAL.U', 'TPGS', 'KVSB', 'STRE.U', 'SCR', 'FWAA', 'HCAQ', 'TBA.U', 'HFEN', 'FSDC', 'ARYA', 'PAND', 'TXAC', 'HECCU', 'CSPR', 'PPD', 'DNK', 'VIE', 'HKIB', 'WSG', 'LVGO', 'PROS', 'MDLA', 'PRVL', 'PRVL', 'PRVL', 'MWK', 'GSX', 'RUHN', 'FHL', 'AVDR', 'THOR', 'OSMT', 'UROV', 'SVMK', 'PRNB', 'CNST'])
filter_ipo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 851 entries, BLTE to DOMO
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Company            851 non-null    object
#  1   Industry           851 non-null    object
#  2   Offer Date         851 non-null    datetime64[ns]
#  3   Shares (millions)  851 non-null    float64
#  4   Offer Price        851 non-null    object
#  5   1st Day Close      851 non-null    object
#  6   Current Price      851 non-null    object
#  7   Return             851 non-null    object
# dtypes: datetime64[ns](1), float64(1), object(6)
# memory usage: 59.8+ KB

# %%
#make copies of the ipo dataframe with times showing 10 days before, 84 days before, and 100 days after 'Offer Date'
ten_days = pd.to_timedelta(10,'days')
three_months = pd.to_timedelta(84,'days')
hundred_days = pd.to_timedelta(100,'days')
filter_ipo['T-10Days'] = filter_ipo['Offer Date']-ten_days
filter_ipo['T-90Days'] = filter_ipo['Offer Date']-three_months
filter_ipo['T+100Days'] = filter_ipo['Offer Date']+hundred_days

# %%
#convert to string for yf useage
filter_ipo['T-10Days'] = filter_ipo['T-10Days'].astype(str)
filter_ipo['T-90Days'] = filter_ipo['T-90Days'].astype(str)
filter_ipo['T+100Days'] = filter_ipo['T+100Days'].astype(str)

# %%
#for ticker in filter_ipo2.index:
#    data3 = spy_returns_ALL.loc[filter_ipo2.loc[ticker,'T-90Days']:filter_ipo2.loc[ticker,'T-10Days']]# [start: end] dates
#    spy_return = (data3.iloc[-1,-2] - data3.iloc[0,-2])/data3.iloc[0,-2]
#    filter_ipo2.loc[ticker,'SPY 90D Return'] = spy_return
#    print(ticker)
#    data2=yf.download(ticker,filter_ipo2.loc[ticker,'Offer Date'], filter_ipo2.loc[ticker,'T+100Days'],progress=True)
#    stock_return = (data2.iloc[-1,-2] - data2.iloc[0,-2])/data2.iloc[0,-2]
#    filter_ipo2.loc[ticker,'100 day Return'] = stock_return

# %% [markdown]
# ## Temporarily Disabled to avoid re-download

# %%
#make copies of the ipo dataframe with times showing 10 days before, 84 days before, and 100 days after 'Offer Date'
for ticker in filter_ipo.index:
    data=yf.download("SPY",filter_ipo.loc[ticker,'T-90Days'], filter_ipo.loc[ticker,'T-10Days'],progress=True)
    spy_return = (data.iloc[-1,-2] - data.iloc[0,-2])/data.iloc[0,-2]
    filter_ipo.loc[ticker,'SPY 90D Return'] = spy_return
    print(ticker)
    data2=yf.download(ticker,filter_ipo.loc[ticker,'Offer Date'], filter_ipo.loc[ticker,'T+100Days'],progress=True)
    stock_return = (data2.iloc[-1,-2] - data2.iloc[0,-2])/data2.iloc[0,-2]
    filter_ipo.loc[ticker,'100 day Return'] = stock_return
# Out:
# [*********************100%***********************]  1 of 1 completed
# BLTE
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# HLVX
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# OST
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# TNON
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# JCSE
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# APLD
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# EE
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# GNS
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# XPON
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ANTX
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# AKAN
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# MGLD
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# BWV
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# MHUA
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# VIVK
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# MDV
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# AREN
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# HTCR
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# SKYX
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ACLX
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# NVCT
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# SSIC
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# CRDO
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# TKLF
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# CISO
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# TPG
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# AMLX
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# CINC
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# HOUR
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# VIGL
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# BNOX
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# IMMX
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# GNTA
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# IOT
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# VINE
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# SIDU
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# HCP
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# NU
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# REFI
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# BIOSU
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# CRECU
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# FINW
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# LITM
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# SG
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# BRZE
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# IREN
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# SEV
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# USER
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ENCPU
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# DERM
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# MYNA
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# BLZE
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# PIK
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# LVLU
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# TIVC
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# VAXX
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# WEAV
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# WBEV
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# CINT
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# EXFY
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# RIVN
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# HTZ
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# SOPA
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# TCBX
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# CIAN
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# IOBT
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# MYNZ
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# RGF
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ARHS
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# CDRE
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# EVO
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# MDXH
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# NRDS
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# BIRD
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# CMTG
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# LIAN
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# AURA
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# TRDA
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# HRT
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# SONX
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# UDMY
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# FLNC
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# GFS
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# DTC
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# AIP
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# INFA
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# MRAI
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# RENT
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# AUGX
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ARIS
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# UTRS
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# XLO
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ENFN
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# PX
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# PTLO
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# RWAY
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# COCO
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# CNTX
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# CYN
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# SDIG
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# INKT
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# FNA
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# GTLB
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# IHS
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# LUCD
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# AVDX
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# HCTI
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# CGTX
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ISO
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# PYXS
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# LTH
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# THRX
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# NVEI
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# VLCN
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# EXAI
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# FWRG
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# TDCX
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# OLPX
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# HCVIU
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# MEKA
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# WRBY
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# AMPL
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# CWAN
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# HLTH
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ARBK
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# BRLT
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ESMT
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# RELY
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# SOVO
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# STER
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# THRN
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# AKA
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# FRSH
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# TOST
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# VBNK
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ACT
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# FORG
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# AEHAU
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# DH
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# DICE
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# BROS
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# EZFL
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ONON
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# PRCT
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# TWKS
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# TYRA
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# SRAD
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# DDI
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# FCUV
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# BTCY
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# AUID
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# SSBK
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ELYM
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ADGI
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# EWCZ
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# OBT
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# WEBR
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# DOLE
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# IMRX
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# INAB
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# OMGA
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# RANI
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# RXST
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# TNYA
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ICVX
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# NUVL
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# RLYB
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# RSKD
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# SWAGU
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# COOK
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# DALS
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# DUOL
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# MLNK
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# PWSC
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# SNPO
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# CADL
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# CRBU
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# CNM
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# CTKB
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# GAMB
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# OB
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# SOPH
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# USCB
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# XPOF
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ABSI
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# BASE
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# INST
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# RYAN
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ZENV
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ZVIA
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# LAW
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# KLTR
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# PYCR
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# VEEE
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# VTEX
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# HCWB
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# BLND
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# BRDG
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ERAS
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# IMGO
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# RGC
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# STVN
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# TCRX
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# FXLV
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# MCG
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# PECO
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# RPID
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# SERA
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# SGHT
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ARYE
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# SNTG
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# RNAZ
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ALCC
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# MITQ
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# NYXH
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ABOS
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# HEPS
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# WAVE
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# EVCM
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# DNUT
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# VRAR
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# CURV
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# AVTE
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# YOU
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# CVRX
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# DIDI
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# IAS
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# LZ
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# CPOP
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# S
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# DNAA
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# DNAB
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# DNAD
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# XMTR
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# DDL
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# GOBI
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ACXP
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# TKNO
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ELEV
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# GHRS
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# GRPH
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# MF
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# MCW
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# BON
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# BHG
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# CFLT
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# DOCS
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# GRVI
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# MIRO
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# GLUE
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# MITAU
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# FA
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# CXM
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# YMM
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# RERE
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# AMAM
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ATAI
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# IPSC
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# DNAY
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# CYT
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# FEMY
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# TRMR
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# AOMR
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ISPC
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# LYEL
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# VERV
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# CNVY
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# MOLN
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# WKME
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ALZN
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# JANX
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# BZ
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# TASK
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# DIBS
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# LFST
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# MNDY
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ZETA
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# MQ
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ZME
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# DLO
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# CNTA
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# DAWN
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# FIGS
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# OMIC
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# DYNS
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# FLYW
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# PAY
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ZIP
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# FWAC
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# OTLY
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# PCOR
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# SQSP
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# VERA
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# GLBE
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# IPW
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# SMWB
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# FLGC
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ANEB
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# BWMN
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# OG
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# TALS
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# WDH
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# VALN
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# FSBC
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# HNST
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# NPCE
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ZY
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# DV
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# SKYT
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# PATH
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# IFBD
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# AKYA
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# BMEA
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# RXRX
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# AGL
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# APP
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# EBET
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# KRT
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# TSP
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ALKT
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# COIN
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# TCVA
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# YTPG
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# RPHM
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# VECT
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# PANA
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# UTME
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# COMP
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ULCC
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# KARO
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# EM
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ACHL
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# COUR
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ALHC
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# DSGN
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# EWTX
# [*********************100%***********************]  1 of 1 completed
# ...
# [*********************100%***********************]  1 of 1 completed
# MEC
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# MIST
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# NXTC
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# SPFI
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# PSN
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# TRVI
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# RRBI
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# SCPL
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# BYND
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# SY
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# TMDX
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# MNRL
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# GNLN
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# HOOK
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# PINS
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ZM
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# TPTX
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# JMIA
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# PD
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# TUFN
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# GHSI
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# SILK
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# TW
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# PBTS
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# LYFT
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# LEVI
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# TIGR
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# SWAV
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# KLDO
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# SLGG
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# HOTH
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# TCRR
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# HARP
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ALEC
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# NFE
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# MTC
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# QFIN
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# TME
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# MRNA
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# MOGU
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# MDRR
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# TC
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# BCSF
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# WEI
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# VAPO
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ETON
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# CNF
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# AXNX
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ORTX
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# TWST
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# GMDA
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# PT
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# YETI
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# LOGC
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# NIU
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# SWI
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# PHAS
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# MSC
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# SIBN
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# PLAN
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# EQ
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ALLO
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# LTHM
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ESTC
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# GH
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# KOD
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# UPWK
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# CTK
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ARVN
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# LAIX
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# RMED
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ARCE
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# CBNK
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ETTX
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# VIOT
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# FTCH
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# STRO
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# YMAB
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# BSVN
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ELAN
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# EB
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# XYF
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# FVCB
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# QTT
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# YI
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# NIO
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ARDS
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# MESA
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# VCNX
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ARLO
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# CWK
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# SONO
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# BRY
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# DAVA
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# OPRA
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# JG
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# CANG
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# FOCS
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# LQDA
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# PDD
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# TENB
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# AQST
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# BE
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# REPL
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ALLK
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ESTA
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# MYFW
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# TLRY
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# CCB
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# CRNX
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# RUBY
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# DOMO
# [*********************100%***********************]  1 of 1 completed

# %%
#checking output
filter_ipo = filter_ipo.fillna(0)

filter_ipo
# Out:
#                                  Company     Industry Offer Date  \
# Symbol
# BLTE                    Belite Bio, Inc.  Health Care 2022-04-29
# HLVX                      HilleVax, Inc.  Health Care 2022-04-29
# OST     Ostin Technology Group Co., Ltd.  Industrials 2022-04-27
# TNON                 Tenon Medical, Inc.  Health Care 2022-04-27
# JCSE       JE Cleantech Holdings Limited  Industrials 2022-04-22
# ...                                  ...          ...        ...
# TLRY                              Tilray  Health Care 2018-07-19
# CCB                    Coastal Financial   Financials 2018-07-18
# CRNX           Crinetics Pharmaceuticals  Health Care 2018-07-18
# RUBY                 Rubius Therapeutics  Health Care 2018-07-18
# DOMO                                Domo   Technology 2018-06-29
#
#         Shares (millions) Offer Price 1st Day Close Current Price   Return  \
# Symbol
# BLTE                  6.0       $6.00        $10.59        $10.59   76.50%
# HLVX                 11.8      $17.00        $19.09        $19.09   12.29%
# OST                   3.4       $4.00        $39.66         $3.70   -7.50%
# TNON                  3.2       $5.00        $22.50        $21.61  332.20%
# JCSE                  3.8       $4.00        $19.00         $4.35    8.75%
# ...                   ...         ...           ...           ...      ...
# TLRY                  9.0      $17.00        $22.39        $46.56  173.88%
# CCB                   2.9      $14.50        $16.40        $15.47    6.69%
# CRNX                  6.0      $17.00        $24.51        $25.00   47.06%
# RUBY                 10.5      $23.00        $24.25        $15.73  -31.61%
# DOMO                  9.2      $21.00        $27.30        $27.32   30.10%
#
#           T-10Days    T-90Days   T+100Days  SPY 90D Return  100 day Return
# Symbol
# BLTE    2022-04-19  2022-02-04  2022-08-07       -0.019324        0.434372
# HLVX    2022-04-19  2022-02-04  2022-08-07       -0.016277       -0.069670
# OST     2022-04-17  2022-02-02  2022-08-05       -0.030467       -0.916793
# TNON    2022-04-17  2022-02-02  2022-08-05       -0.030467        0.612444
# JCSE    2022-04-12  2022-01-28  2022-07-31        0.023297       -0.618947
# ...            ...         ...         ...             ...             ...
# TLRY    2018-07-09  2018-04-26  2018-10-27        0.049413        3.827155
# CCB     2018-07-08  2018-04-25  2018-10-26        0.052007       -0.053383
# CRNX    2018-07-08  2018-04-25  2018-10-26        0.052007        0.019992
# RUBY    2018-07-08  2018-04-25  2018-10-26        0.052007       -0.325458
# DOMO    2018-06-19  2018-04-06  2018-10-07        0.045783       -0.301099
#
# [851 rows x 13 columns]

# %%
# Saving dataframe to csv to avoid 25min wait re-downloading date when restarting kernel

filter_ipo.to_csv('ipo_downloaded_data.csv')

y_scrape_ipo = pd.read_csv('ipo_downloaded_data.csv')

# %%
#Reading the downloaded data from CSV
filter_ipo = pd.read_csv('ipo_downloaded_data.csv')
filter_ipo.set_index('Symbol',inplace=True)
filter_ipo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 851 entries, BLTE to DOMO
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Company            851 non-null    object
#  1   Industry           851 non-null    object
#  2   Offer Date         851 non-null    object
#  3   Shares (millions)  851 non-null    float64
#  4   Offer Price        851 non-null    object
#  5   1st Day Close      851 non-null    object
#  6   Current Price      851 non-null    object
#  7   Return             851 non-null    object
#  8   T-10Days           851 non-null    object
#  9   T-90Days           851 non-null    object
#  10  T+100Days          851 non-null    object
#  11  SPY 90D Return     851 non-null    float64
#  12  100 day Return     851 non-null    float64
# dtypes: float64(3), object(10)
# memory usage: 93.1+ KB

# %%
filter_ipo['Offer Date'] =  pd.to_datetime(filter_ipo['Offer Date'], format='%Y-%m-%d')
filter_ipo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 851 entries, BLTE to DOMO
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Company            851 non-null    object
#  1   Industry           851 non-null    object
#  2   Offer Date         851 non-null    datetime64[ns]
#  3   Shares (millions)  851 non-null    float64
#  4   Offer Price        851 non-null    object
#  5   1st Day Close      851 non-null    object
#  6   Current Price      851 non-null    object
#  7   Return             851 non-null    object
#  8   T-10Days           851 non-null    object
#  9   T-90Days           851 non-null    object
#  10  T+100Days          851 non-null    object
#  11  SPY 90D Return     851 non-null    float64
#  12  100 day Return     851 non-null    float64
# dtypes: datetime64[ns](1), float64(3), object(9)
# memory usage: 93.1+ KB

# %%
# Encode Offer Date to week of year
for ticker in filter_ipo.index:
    filter_ipo.loc[ticker,'Offer Date'] = filter_ipo.loc[ticker,'Offer Date'].isocalendar()[1]

# %%
# Create binary encoded column for whether or not stock saw positive gains after 100 days
returns_bin = []
for pct in filter_ipo['100 day Return']:
    if pct >= 0:
        returns_bin.append(1)
    else:
        returns_bin.append(0)
        
filter_ipo['100D Y/N'] = returns_bin

#Encoding "Industry" Column
le = LabelEncoder()
le.fit(filter_ipo["Industry"])
filter_ipo["Industry"] = le.transform(filter_ipo["Industry"])

# Drop unecessary date columns
#filter_ipo.drop(columns=['T-10Days','T-90Days','T+100Days'], inplace=True)

# %%
# Use  to create categorized lists of Yahoo Finance CSV's for parsing
bs_df = pd.read_csv("YF_scrap_data.csv")
#list_of_lists = [bs_list]

#filtered_ipo=ipo_csv.drop(columns=["1st Day Close"])
bs_df.set_index('Symbol',inplace=True)

bs_df
# Out:
#                        Date  Research Development  \
# Symbol
# RACB    2021-12-31 00:00:00                   NaN
# RACB    2020-12-31 00:00:00                   NaN
# TUYA    2021-12-31 00:00:00           174289000.0
# TUYA    2020-12-31 00:00:00            77430000.0
# TUYA    2019-12-31 00:00:00            52003000.0
# ...                     ...                   ...
# RUBY    2018-12-31 00:00:00            51769000.0
# DOMO    2021-01-31 00:00:00            66474000.0
# DOMO    2020-01-31 00:00:00            69224000.0
# DOMO    2019-01-31 00:00:00            75740000.0
# DOMO    2018-01-31 00:00:00            78261000.0
#
#         Effect Of Accounting Charges  Income Before Tax  Minority Interest  \
# Symbol
# RACB                             NaN          -456005.0                NaN
# RACB                             NaN           -18874.0                NaN
# TUYA                             NaN       -174934000.0                NaN
# TUYA                             NaN        -66706000.0                NaN
# TUYA                             NaN        -70353000.0                NaN
# ...                              ...                ...                ...
# RUBY                             NaN        -89195000.0                NaN
# DOMO                             NaN        -84225000.0                NaN
# DOMO                             NaN       -124902000.0                NaN
# DOMO                             NaN       -153061000.0                NaN
# DOMO                             NaN       -176177000.0                NaN
#
#          Net Income  Selling General Administrative  Gross Profit  \
# Symbol
# RACB      -456005.0                             NaN           0.0
# RACB       -18874.0                             NaN           0.0
# TUYA   -175424000.0                     146973000.0   127867000.0
# TUYA    -66912000.0                      55424000.0    61937000.0
# TUYA    -70477000.0                      49213000.0    27786000.0
# ...             ...                             ...           ...
# RUBY    -89195000.0                      39894000.0           0.0
# DOMO    -84634000.0                     159243000.0   153432000.0
# DOMO   -125656000.0                     164808000.0   117465000.0
# DOMO   -154309000.0                     161257000.0    92910000.0
# DOMO   -176562000.0                     161125000.0    63605000.0
#
#                Ebit  Operating Income  ...  Change To Inventory  \
# Symbol                                 ...
# RACB            0.0               NaN  ...                  NaN
# RACB            0.0               NaN  ...                  NaN
# TUYA   -183560000.0      -183560000.0  ...          -22121000.0
# TUYA    -69846000.0       -69846000.0  ...          -19787000.0
# TUYA    -73440000.0       -73440000.0  ...          -11037000.0
# ...             ...               ...  ...                  ...
# RUBY    -91663000.0       -91663000.0  ...                  NaN
# DOMO    -72729000.0       -72729000.0  ...                  NaN
# DOMO   -115457000.0      -115457000.0  ...                  NaN
# DOMO   -144117000.0      -144117000.0  ...                  NaN
# DOMO   -175817000.0      -175817000.0  ...                  NaN
#
#         Change To Account Receivables  Capital Expenditures  \
# Symbol
# RACB                              NaN                   NaN
# RACB                              NaN                   NaN
# TUYA                      -23430000.0            -6193000.0
# TUYA                       -7243000.0            -3201000.0
# TUYA                       -4010000.0            -2487000.0
# ...                               ...                   ...
# RUBY                              NaN           -14952000.0
# DOMO                        -305000.0            -5706000.0
# DOMO                         454000.0            -6466000.0
# DOMO                      -12937000.0            -6373000.0
# DOMO                      -13186000.0            -7281000.0
#
#         Intangible Assets  Deferred Long Term Asset Charges  Dividends Paid  \
# Symbol
# RACB                  NaN                               NaN             NaN
# RACB                  NaN                               NaN             NaN
# TUYA                  NaN                               NaN             NaN
# TUYA                  NaN                               NaN             NaN
# TUYA                  NaN                               NaN             NaN
# ...                   ...                               ...             ...
# RUBY                  NaN                               NaN             NaN
# DOMO            3356000.0                               NaN             NaN
# DOMO            3865000.0                               NaN             NaN
# DOMO            4415000.0                               NaN             NaN
# DOMO            3026000.0                               NaN             NaN
#
#         Good Will  Long Term Debt  Short Long Term Debt  Minority Interest.1
# Symbol
# RACB          NaN             NaN                   NaN                  NaN
# RACB          NaN             NaN                   NaN                  NaN
# TUYA          NaN             NaN                   NaN                  NaN
# TUYA          NaN             NaN                   NaN                  NaN
# TUYA          NaN             NaN                   NaN                  NaN
# ...           ...             ...                   ...                  ...
# RUBY          NaN      24347000.0                   NaN                  NaN
# DOMO    9478000.0      99609000.0                   NaN                  NaN
# DOMO    9478000.0     101074000.0                   NaN                  NaN
# DOMO    9478000.0      97245000.0                   NaN                  NaN
# DOMO    9478000.0      46332000.0                   NaN                  NaN
#
# [2025 rows x 72 columns]

# %%
# Clean and organize CSV
#def step_1(frame):
    #frame_df = frame.set_index('Ticker')
    
    # Delete TTM column as this data may be more recent than date of IPO
    #if 'ttm' in frame_df.columns: 
        #frame_df.drop(columns = 'ttm',inplace=True)
    #else:
        #pass
    
    # Keep only latest annual financial data from year prior to IPO
    #if len(frame_df) == 0:
        #pass
    #else:
    #    frame_df = frame_df.iloc[:,0]
    
    # Fill NaN's
    #    frame_df = pd.DataFrame(frame_df.fillna(0))
    
    # Transpose DataFrame
    #    frame_df = frame_df.T
    
    # Standardize index
    #    frame_df = frame_df.reset_index()
    
    #Remove '\t...' from column names
    #    frame_df.columns = frame_df.columns.str.strip()
    
     #   return frame_df

# %%
#Create dataframe for CSV per respective category
#def step_2(list):
    #df = pd.DataFrame()
    
    # Loop through each list of YF Financials and clean CSV
    #for file in list:
        
        # Read in CSV
        #path = Path(file)
        #csv = pd.read_csv(path, engine='python')
        
        # Clean CSV using step_1 function
        #step = step_1(csv)
        
        # Add data from csv to df
        #df = pd.concat([df,step], axis = 0)
        
        # Fill NaNs
        #df = df.fillna(0)
        
        # Remove "\t" from column names
        #df.columns = df.columns.str.strip()
        
        # Reset index
        #df.reset_index(drop=True, inplace=True)
        
        # Drop useless column
        #df.drop(columns='index',inplace=True)
    
    # Loop through columns and drop columns that have 0 for more than 20% of the data therein
    #for column in df.columns[1:]:
    #    zeros = (df[column]==0).sum()
    #    if zeros >= 0.8*len(df.index):
    #        df.drop(columns = column, inplace = True)
    #    else:
    #        pass
    
    #return df

# %%
# Create dataframe concatenated from respective categorical dataframes
#def step_3(list):
##    df = pd.DataFrame()
#    tickers = []
    
    # Loop through each list of respective YF CSVs
#    for l in list_of_lists:
        
        #Clean and concatenate CSV based on category
#        frame = step_2(l)
#        df = pd.concat([df,frame],axis=1)
    
    # Drop random NaN row?
#    print(len(df))
    #df = df.dropna()
    
    #Clean and update index for syntax
#    for name in bs_list:
#        tickers.append(name[:4])

#    df.index = tickers
    
#    for x in df.index:
#        if x[3] == '_':
##             df.rename(index={x:x[:3]},inplace=True)
#        elif x[2] == '_':
#            df.rename(index={x:x[:2]},inplace=True)
#        elif x[1] == '_':
#            df.rename(index={x:x[:1]},inplace=True)
#        else:
#            pass
    
#    return df

# %%
#Running Functions and Compiling DFs
#bs_df = step_3(list_of_lists)
bz_ipo_df = pd.concat([bs_df, filter_ipo])
#bz_ipo_df.set_index('Symbol',inplace=True)
bz_ipo_df.drop(columns='Return', inplace=True)
bz_ipo_df = bz_ipo_df.fillna(0)
#bz_ipo_df.set_index('Industry',inplace=True)
#bz_ipo_df = bz_ipo_df.drop(columns='Symbol')
bz_ipo_df.tail
# Out:
# <bound method NDFrame.tail of                        Date  Research Development  \
# Symbol
# RACB    2021-12-31 00:00:00                   0.0
# RACB    2020-12-31 00:00:00                   0.0
# TUYA    2021-12-31 00:00:00           174289000.0
# TUYA    2020-12-31 00:00:00            77430000.0
# TUYA    2019-12-31 00:00:00            52003000.0
# ...                     ...                   ...
# TLRY                      0                   0.0
# CCB                       0                   0.0
# CRNX                      0                   0.0
# RUBY                      0                   0.0
# DOMO                      0                   0.0
#
#         Effect Of Accounting Charges  Income Before Tax  Minority Interest  \
# Symbol
# RACB                             0.0          -456005.0                0.0
# RACB                             0.0           -18874.0                0.0
# TUYA                             0.0       -174934000.0                0.0
# TUYA                             0.0        -66706000.0                0.0
# TUYA                             0.0        -70353000.0                0.0
# ...                              ...                ...                ...
# TLRY                             0.0                0.0                0.0
# CCB                              0.0                0.0                0.0
# CRNX                             0.0                0.0                0.0
# RUBY                             0.0                0.0                0.0
# DOMO                             0.0                0.0                0.0
#
#          Net Income  Selling General Administrative  Gross Profit  \
# Symbol
# RACB      -456005.0                             0.0           0.0
# RACB       -18874.0                             0.0           0.0
# TUYA   -175424000.0                     146973000.0   127867000.0
# TUYA    -66912000.0                      55424000.0    61937000.0
# TUYA    -70477000.0                      49213000.0    27786000.0
# ...             ...                             ...           ...
# TLRY            0.0                             0.0           0.0
# CCB             0.0                             0.0           0.0
# CRNX            0.0                             0.0           0.0
# RUBY            0.0                             0.0           0.0
# DOMO            0.0                             0.0           0.0
#
#                Ebit  Operating Income  ...  Shares (millions)  Offer Price  \
# Symbol                                 ...
# RACB            0.0               0.0  ...                0.0            0
# RACB            0.0               0.0  ...                0.0            0
# TUYA   -183560000.0      -183560000.0  ...                0.0            0
# TUYA    -69846000.0       -69846000.0  ...                0.0            0
# TUYA    -73440000.0       -73440000.0  ...                0.0            0
# ...             ...               ...  ...                ...          ...
# TLRY            0.0               0.0  ...                9.0       $17.00
# CCB             0.0               0.0  ...                2.9       $14.50
# CRNX            0.0               0.0  ...                6.0       $17.00
# RUBY            0.0               0.0  ...               10.5       $23.00
# DOMO            0.0               0.0  ...                9.2       $21.00
#
#         1st Day Close  Current Price    T-10Days    T-90Days   T+100Days  \
# Symbol
# RACB                0              0           0           0           0
# RACB                0              0           0           0           0
# TUYA                0              0           0           0           0
# TUYA                0              0           0           0           0
# TUYA                0              0           0           0           0
# ...               ...            ...         ...         ...         ...
# TLRY           $22.39         $46.56  2018-07-09  2018-04-26  2018-10-27
# CCB            $16.40         $15.47  2018-07-08  2018-04-25  2018-10-26
# CRNX           $24.51         $25.00  2018-07-08  2018-04-25  2018-10-26
# RUBY           $24.25         $15.73  2018-07-08  2018-04-25  2018-10-26
# DOMO           $27.30         $27.32  2018-06-19  2018-04-06  2018-10-07
#
#         SPY 90D Return  100 day Return  100D Y/N
# Symbol
# RACB          0.000000        0.000000       0.0
# RACB          0.000000        0.000000       0.0
# TUYA          0.000000        0.000000       0.0
# TUYA          0.000000        0.000000       0.0
# TUYA          0.000000        0.000000       0.0
# ...                ...             ...       ...
# TLRY          0.049413        3.827155       1.0
# CCB           0.052007       -0.053383       0.0
# CRNX          0.052007        0.019992       1.0
# RUBY          0.052007       -0.325458       0.0
# DOMO          0.045783       -0.301099       0.0
#
# [2876 rows x 85 columns]>

# %%
bz_ipo_df.loc[:,'Industry'] = bz_ipo_df.loc[:,'Industry'].astype(str)
bz_ipo_df.loc[:,'100D Y/N'] = bz_ipo_df.loc[:,'100D Y/N'].astype(str)

# %%
for column in bz_ipo_df.columns:
    bz_ipo_df.loc[:,column] = bz_ipo_df.loc[:,column].astype(str)
    bz_ipo_df.loc[:,column] = bz_ipo_df.loc[:,column].str.replace('$','')
    bz_ipo_df.loc[:,column] = bz_ipo_df.loc[:,column].str.replace(',','')
    #.astype(float)
# Out:
# /var/folders/tb/p0ymc44s2sqb8g6stzd8f2pm0000gn/T/ipykernel_11731/3963379596.py:3: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   bz_ipo_df.loc[:,column] = bz_ipo_df.loc[:,column].str.replace('$','')

# %%
bz_ipo_df['100D Y/N'].value_counts()
# Out:
# 0.0    2544
# 1.0     332
# Name: 100D Y/N, dtype: int64

# %%
bz_ipo_df
# Out:
#                        Date Research Development Effect Of Accounting Charges  \
# Symbol
# RACB    2021-12-31 00:00:00                  0.0                          0.0
# RACB    2020-12-31 00:00:00                  0.0                          0.0
# TUYA    2021-12-31 00:00:00          174289000.0                          0.0
# TUYA    2020-12-31 00:00:00           77430000.0                          0.0
# TUYA    2019-12-31 00:00:00           52003000.0                          0.0
# ...                     ...                  ...                          ...
# TLRY                      0                  0.0                          0.0
# CCB                       0                  0.0                          0.0
# CRNX                      0                  0.0                          0.0
# RUBY                      0                  0.0                          0.0
# DOMO                      0                  0.0                          0.0
#
#        Income Before Tax Minority Interest    Net Income  \
# Symbol
# RACB           -456005.0               0.0     -456005.0
# RACB            -18874.0               0.0      -18874.0
# TUYA        -174934000.0               0.0  -175424000.0
# TUYA         -66706000.0               0.0   -66912000.0
# TUYA         -70353000.0               0.0   -70477000.0
# ...                  ...               ...           ...
# TLRY                 0.0               0.0           0.0
# CCB                  0.0               0.0           0.0
# CRNX                 0.0               0.0           0.0
# RUBY                 0.0               0.0           0.0
# DOMO                 0.0               0.0           0.0
#
#        Selling General Administrative Gross Profit          Ebit  \
# Symbol
# RACB                              0.0          0.0           0.0
# RACB                              0.0          0.0           0.0
# TUYA                      146973000.0  127867000.0  -183560000.0
# TUYA                       55424000.0   61937000.0   -69846000.0
# TUYA                       49213000.0   27786000.0   -73440000.0
# ...                               ...          ...           ...
# TLRY                              0.0          0.0           0.0
# CCB                               0.0          0.0           0.0
# CRNX                              0.0          0.0           0.0
# RUBY                              0.0          0.0           0.0
# DOMO                              0.0          0.0           0.0
#
#        Operating Income  ... Shares (millions) Offer Price 1st Day Close  \
# Symbol                   ...
# RACB                0.0  ...               0.0           0             0
# RACB                0.0  ...               0.0           0             0
# TUYA       -183560000.0  ...               0.0           0             0
# TUYA        -69846000.0  ...               0.0           0             0
# TUYA        -73440000.0  ...               0.0           0             0
# ...                 ...  ...               ...         ...           ...
# TLRY                0.0  ...               9.0       17.00         22.39
# CCB                 0.0  ...               2.9       14.50         16.40
# CRNX                0.0  ...               6.0       17.00         24.51
# RUBY                0.0  ...              10.5       23.00         24.25
# DOMO                0.0  ...               9.2       21.00         27.30
#
#        Current Price    T-10Days    T-90Days   T+100Days      SPY 90D Return  \
# Symbol
# RACB               0           0           0           0                 0.0
# RACB               0           0           0           0                 0.0
# TUYA               0           0           0           0                 0.0
# TUYA               0           0           0           0                 0.0
# TUYA               0           0           0           0                 0.0
# ...              ...         ...         ...         ...                 ...
# TLRY           46.56  2018-07-09  2018-04-26  2018-10-27  0.0494131092766138
# CCB            15.47  2018-07-08  2018-04-25  2018-10-26  0.0520070303347212
# CRNX           25.00  2018-07-08  2018-04-25  2018-10-26  0.0520070303347212
# RUBY           15.73  2018-07-08  2018-04-25  2018-10-26  0.0520068342455622
# DOMO           27.32  2018-06-19  2018-04-06  2018-10-07  0.0457830095109218
#
#              100 day Return 100D Y/N
# Symbol
# RACB                    0.0      0.0
# RACB                    0.0      0.0
# TUYA                    0.0      0.0
# TUYA                    0.0      0.0
# TUYA                    0.0      0.0
# ...                     ...      ...
# TLRY      3.827155193270049      1.0
# CCB     -0.0533830277944846      0.0
# CRNX     0.0199918305402854      1.0
# RUBY    -0.3254582492636702      0.0
# DOMO     -0.301098884361711      0.0
#
# [2876 rows x 85 columns]

# %%
# Split and scale data
#bz_ipo_df.drop(bz_ipo_df.columns[['100 day Return', 'Company']], axis = 1, inplace = True)
bz_ipo_df1=bz_ipo_df.drop(columns=['100 day Return', 'Company', 'T-10Days' , 'T-90Days' , 'T+100Days' ])

# %%
bz_ipo_df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2876 entries, RACB to DOMO
# Data columns (total 80 columns):
#  #   Column                                     Non-Null Count  Dtype
# ---  ------                                     --------------  -----
#  0   Date                                       2876 non-null   object
#  1   Research Development                       2876 non-null   object
#  2   Effect Of Accounting Charges               2876 non-null   object
#  3   Income Before Tax                          2876 non-null   object
#  4   Minority Interest                          2876 non-null   object
#  5   Net Income                                 2876 non-null   object
#  6   Selling General Administrative             2876 non-null   object
#  7   Gross Profit                               2876 non-null   object
#  8   Ebit                                       2876 non-null   object
#  9   Operating Income                           2876 non-null   object
#  10  Other Operating Expenses                   2876 non-null   object
#  11  Interest Expense                           2876 non-null   object
#  12  Extraordinary Items                        2876 non-null   object
#  13  Non Recurring                              2876 non-null   object
#  14  Other Items                                2876 non-null   object
#  15  Income Tax Expense                         2876 non-null   object
#  16  Total Revenue                              2876 non-null   object
#  17  Total Operating Expenses                   2876 non-null   object
#  18  Cost Of Revenue                            2876 non-null   object
#  19  Total Other Income Expense Net             2876 non-null   object
#  20  Discontinued Operations                    2876 non-null   object
#  21  Net Income From Continuing Ops             2876 non-null   object
#  22  Net Income Applicable To Common Shares     2876 non-null   object
#  23  Total Liab                                 2876 non-null   object
#  24  Total Stockholder Equity                   2876 non-null   object
#  25  Total Assets                               2876 non-null   object
#  26  Common Stock                               2876 non-null   object
#  27  Retained Earnings                          2876 non-null   object
#  28  Other Liab                                 2876 non-null   object
#  29  Other Assets                               2876 non-null   object
#  30  Cash                                       2876 non-null   object
#  31  Total Current Liabilities                  2876 non-null   object
#  32  Total Current Assets                       2876 non-null   object
#  33  Net Tangible Assets                        2876 non-null   object
#  34  Accounts Payable                           2876 non-null   object
#  35  Capital Surplus                            2876 non-null   object
#  36  Deferred Long Term Liab                    2876 non-null   object
#  37  Change To Liabilities                      2876 non-null   object
#  38  Total Cashflows From Investing Activities  2876 non-null   object
#  39  Net Borrowings                             2876 non-null   object
#  40  Total Cash From Financing Activities       2876 non-null   object
#  41  Change To Operating Activities             2876 non-null   object
#  42  Issuance Of Stock                          2876 non-null   object
#  43  Net Income.1                               2876 non-null   object
#  44  Change In Cash                             2876 non-null   object
#  45  Total Cash From Operating Activities       2876 non-null   object
#  46  Other Cashflows From Investing Activities  2876 non-null   object
#  47  Other Cashflows From Financing Activities  2876 non-null   object
#  48  Change To Netincome                        2876 non-null   object
#  49  Other Current Liab                         2876 non-null   object
#  50  Other Current Assets                       2876 non-null   object
#  51  Treasury Stock                             2876 non-null   object
#  52  Other Stockholder Equity                   2876 non-null   object
#  53  Property Plant Equipment                   2876 non-null   object
#  54  Long Term Investments                      2876 non-null   object
#  55  Short Term Investments                     2876 non-null   object
#  56  Net Receivables                            2876 non-null   object
#  57  Inventory                                  2876 non-null   object
#  58  Investments                                2876 non-null   object
#  59  Repurchase Of Stock                        2876 non-null   object
#  60  Effect Of Exchange Rate                    2876 non-null   object
#  61  Depreciation                               2876 non-null   object
#  62  Change To Inventory                        2876 non-null   object
#  63  Change To Account Receivables              2876 non-null   object
#  64  Capital Expenditures                       2876 non-null   object
#  65  Intangible Assets                          2876 non-null   object
#  66  Deferred Long Term Asset Charges           2876 non-null   object
#  67  Dividends Paid                             2876 non-null   object
#  68  Good Will                                  2876 non-null   object
#  69  Long Term Debt                             2876 non-null   object
#  70  Short Long Term Debt                       2876 non-null   object
#  71  Minority Interest.1                        2876 non-null   object
#  72  Industry                                   2876 non-null   object
#  73  Offer Date                                 2876 non-null   object
#  74  Shares (millions)                          2876 non-null   object
#  75  Offer Price                                2876 non-null   object
#  76  1st Day Close                              2876 non-null   object
#  77  Current Price                              2876 non-null   object
#  78  SPY 90D Return                             2876 non-null   object
#  79  100D Y/N                                   2876 non-null   object
# dtypes: object(80)
# memory usage: 1.8+ MB

# %%
# Convert df objects to int or float
bz_ipo_df1["Industry"] = pd.to_numeric(bz_ipo_df1["Industry"])
bz_ipo_df1["Offer Date"] = pd.to_numeric(bz_ipo_df1["Offer Date"])
bz_ipo_df1["Shares (millions)"] = pd.to_numeric(bz_ipo_df1["Shares (millions)"])
bz_ipo_df1["Offer Price"] = pd.to_numeric(bz_ipo_df1["Offer Price"])
bz_ipo_df1["Current Price"] = pd.to_numeric(bz_ipo_df1["Current Price"])
bz_ipo_df1["SPY 90D Return"] = pd.to_numeric(bz_ipo_df1["SPY 90D Return"])
bz_ipo_df1["100D Y/N"] = pd.to_numeric(bz_ipo_df1["100D Y/N"])
bz_ipo_df1["1st Day Close"] = pd.to_numeric(bz_ipo_df1["1st Day Close"])
bz_ipo_df1["100D Y/N"] = pd.to_numeric(bz_ipo_df1["100D Y/N"])
bz_ipo_df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2876 entries, RACB to DOMO
# Data columns (total 80 columns):
#  #   Column                                     Non-Null Count  Dtype
# ---  ------                                     --------------  -----
#  0   Date                                       2876 non-null   object
#  1   Research Development                       2876 non-null   object
#  2   Effect Of Accounting Charges               2876 non-null   object
#  3   Income Before Tax                          2876 non-null   object
#  4   Minority Interest                          2876 non-null   object
#  5   Net Income                                 2876 non-null   object
#  6   Selling General Administrative             2876 non-null   object
#  7   Gross Profit                               2876 non-null   object
#  8   Ebit                                       2876 non-null   object
#  9   Operating Income                           2876 non-null   object
#  10  Other Operating Expenses                   2876 non-null   object
#  11  Interest Expense                           2876 non-null   object
#  12  Extraordinary Items                        2876 non-null   object
#  13  Non Recurring                              2876 non-null   object
#  14  Other Items                                2876 non-null   object
#  15  Income Tax Expense                         2876 non-null   object
#  16  Total Revenue                              2876 non-null   object
#  17  Total Operating Expenses                   2876 non-null   object
#  18  Cost Of Revenue                            2876 non-null   object
#  19  Total Other Income Expense Net             2876 non-null   object
#  20  Discontinued Operations                    2876 non-null   object
#  21  Net Income From Continuing Ops             2876 non-null   object
#  22  Net Income Applicable To Common Shares     2876 non-null   object
#  23  Total Liab                                 2876 non-null   object
#  24  Total Stockholder Equity                   2876 non-null   object
#  25  Total Assets                               2876 non-null   object
#  26  Common Stock                               2876 non-null   object
#  27  Retained Earnings                          2876 non-null   object
#  28  Other Liab                                 2876 non-null   object
#  29  Other Assets                               2876 non-null   object
#  30  Cash                                       2876 non-null   object
#  31  Total Current Liabilities                  2876 non-null   object
#  32  Total Current Assets                       2876 non-null   object
#  33  Net Tangible Assets                        2876 non-null   object
#  34  Accounts Payable                           2876 non-null   object
#  35  Capital Surplus                            2876 non-null   object
#  36  Deferred Long Term Liab                    2876 non-null   object
#  37  Change To Liabilities                      2876 non-null   object
#  38  Total Cashflows From Investing Activities  2876 non-null   object
#  39  Net Borrowings                             2876 non-null   object
#  40  Total Cash From Financing Activities       2876 non-null   object
#  41  Change To Operating Activities             2876 non-null   object
#  42  Issuance Of Stock                          2876 non-null   object
#  43  Net Income.1                               2876 non-null   object
#  44  Change In Cash                             2876 non-null   object
#  45  Total Cash From Operating Activities       2876 non-null   object
#  46  Other Cashflows From Investing Activities  2876 non-null   object
#  47  Other Cashflows From Financing Activities  2876 non-null   object
#  48  Change To Netincome                        2876 non-null   object
#  49  Other Current Liab                         2876 non-null   object
#  50  Other Current Assets                       2876 non-null   object
#  51  Treasury Stock                             2876 non-null   object
#  52  Other Stockholder Equity                   2876 non-null   object
#  53  Property Plant Equipment                   2876 non-null   object
#  54  Long Term Investments                      2876 non-null   object
#  55  Short Term Investments                     2876 non-null   object
#  56  Net Receivables                            2876 non-null   object
#  57  Inventory                                  2876 non-null   object
#  58  Investments                                2876 non-null   object
#  59  Repurchase Of Stock                        2876 non-null   object
#  60  Effect Of Exchange Rate                    2876 non-null   object
#  61  Depreciation                               2876 non-null   object
#  62  Change To Inventory                        2876 non-null   object
#  63  Change To Account Receivables              2876 non-null   object
#  64  Capital Expenditures                       2876 non-null   object
#  65  Intangible Assets                          2876 non-null   object
#  66  Deferred Long Term Asset Charges           2876 non-null   object
#  67  Dividends Paid                             2876 non-null   object
#  68  Good Will                                  2876 non-null   object
#  69  Long Term Debt                             2876 non-null   object
#  70  Short Long Term Debt                       2876 non-null   object
#  71  Minority Interest.1                        2876 non-null   object
#  72  Industry                                   2876 non-null   float64
#  73  Offer Date                                 2876 non-null   int64
#  74  Shares (millions)                          2876 non-null   float64
#  75  Offer Price                                2876 non-null   float64
#  76  1st Day Close                              2876 non-null   float64
#  77  Current Price                              2876 non-null   float64
#  78  SPY 90D Return                             2876 non-null   float64
#  79  100D Y/N                                   2876 non-null   float64
# dtypes: float64(7), int64(1), object(72)
# memory usage: 1.8+ MB

# %%
# Add more Features
# Computing 1st Day return
bz_ipo_df1['1st Day Close Return'] = (bz_ipo_df1['1st Day Close']-bz_ipo_df1['Offer Price'])/bz_ipo_df1['Offer Price']
#bz_ipo_df1 = bz_ipo_df1.drop(columns=["1st Day Close"])
#Computing Market Cap
bz_ipo_df1['Market Cap'] = (bz_ipo_df1['Offer Price'] * bz_ipo_df1['Shares (millions)'])* 1000000
bz_ipo_df1['Shares (millions)'] = bz_ipo_df1['Shares (millions)'] * 1000000
bz_ipo_df1 = bz_ipo_df1.dropna()
bz_ipo_df1
# Out:
#        Date Research Development Effect Of Accounting Charges  \
# Symbol
# BLTE      0                  0.0                          0.0
# HLVX      0                  0.0                          0.0
# OST       0                  0.0                          0.0
# TNON      0                  0.0                          0.0
# JCSE      0                  0.0                          0.0
# ...     ...                  ...                          ...
# TLRY      0                  0.0                          0.0
# CCB       0                  0.0                          0.0
# CRNX      0                  0.0                          0.0
# RUBY      0                  0.0                          0.0
# DOMO      0                  0.0                          0.0
#
#        Income Before Tax Minority Interest Net Income  \
# Symbol
# BLTE                 0.0               0.0        0.0
# HLVX                 0.0               0.0        0.0
# OST                  0.0               0.0        0.0
# TNON                 0.0               0.0        0.0
# JCSE                 0.0               0.0        0.0
# ...                  ...               ...        ...
# TLRY                 0.0               0.0        0.0
# CCB                  0.0               0.0        0.0
# CRNX                 0.0               0.0        0.0
# RUBY                 0.0               0.0        0.0
# DOMO                 0.0               0.0        0.0
#
#        Selling General Administrative Gross Profit Ebit Operating Income  ...  \
# Symbol                                                                    ...
# BLTE                              0.0          0.0  0.0              0.0  ...
# HLVX                              0.0          0.0  0.0              0.0  ...
# OST                               0.0          0.0  0.0              0.0  ...
# TNON                              0.0          0.0  0.0              0.0  ...
# JCSE                              0.0          0.0  0.0              0.0  ...
# ...                               ...          ...  ...              ...  ...
# TLRY                              0.0          0.0  0.0              0.0  ...
# CCB                               0.0          0.0  0.0              0.0  ...
# CRNX                              0.0          0.0  0.0              0.0  ...
# RUBY                              0.0          0.0  0.0              0.0  ...
# DOMO                              0.0          0.0  0.0              0.0  ...
#
#        Industry Offer Date Shares (millions) Offer Price 1st Day Close  \
# Symbol
# BLTE        5.0         17         6000000.0         6.0         10.59
# HLVX        5.0         17        11800000.0        17.0         19.09
# OST         6.0         17         3400000.0         4.0         39.66
# TNON        5.0         17         3200000.0         5.0         22.50
# JCSE        6.0         16         3800000.0         4.0         19.00
# ...         ...        ...               ...         ...           ...
# TLRY        5.0         29         9000000.0        17.0         22.39
# CCB         4.0         29         2900000.0        14.5         16.40
# CRNX        5.0         29         6000000.0        17.0         24.51
# RUBY        5.0         29        10500000.0        23.0         24.25
# DOMO        9.0         26         9200000.0        21.0         27.30
#
#        Current Price SPY 90D Return 100D Y/N 1st Day Close Return   Market Cap
# Symbol
# BLTE           10.59      -0.019324      1.0             0.765000   36000000.0
# HLVX           19.09      -0.016277      0.0             0.122941  200600000.0
# OST             3.70      -0.030467      0.0             8.915000   13600000.0
# TNON           21.61      -0.030467      1.0             3.500000   16000000.0
# JCSE            4.35       0.023297      0.0             3.750000   15200000.0
# ...              ...            ...      ...                  ...          ...
# TLRY           46.56       0.049413      1.0             0.317059  153000000.0
# CCB            15.47       0.052007      0.0             0.131034   42050000.0
# CRNX           25.00       0.052007      1.0             0.441765  102000000.0
# RUBY           15.73       0.052007      0.0             0.054348  241500000.0
# DOMO           27.32       0.045783      0.0             0.300000  193200000.0
#
# [851 rows x 82 columns]

# %%
# Rearrange Columns in dataframe
bz_ipo_df1 = bz_ipo_df1[["Industry", "Offer Date", "Shares (millions)","Offer Price" ,"1st Day Close" ,"Current Price" ,"SPY 90D Return" ,"1st Day Close Return", "Market Cap", "100D Y/N"	  ]]
#bz_ipo_df1=bz_ipo_df.drop(columns=["1st Day Close"])
bz_ipo_df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 851 entries, BLTE to DOMO
# Data columns (total 10 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Industry              851 non-null    float64
#  1   Offer Date            851 non-null    int64
#  2   Shares (millions)     851 non-null    float64
#  3   Offer Price           851 non-null    float64
#  4   1st Day Close         851 non-null    float64
#  5   Current Price         851 non-null    float64
#  6   SPY 90D Return        851 non-null    float64
#  7   1st Day Close Return  851 non-null    float64
#  8   Market Cap            851 non-null    float64
#  9   100D Y/N              851 non-null    float64
# dtypes: float64(9), int64(1)
# memory usage: 73.1+ KB

# %%
# Split Train and Test
X = bz_ipo_df1.iloc[:, 0:-1]
y = bz_ipo_df1.iloc[:, -1]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=69)
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
# Use RandomOverSampler to balance data
ros = RandomOverSampler(random_state=1)
X_resampled, y_resampled = ros.fit_resample(X_train, y_train)

# %% [markdown]
# ## Random Forest Classifier

# %%
from sklearn.ensemble import RandomForestClassifier

#Create an RF Classifier
clf_rf=RandomForestClassifier(n_estimators=1000, random_state=1)

#Train the model using the training sets y_pred=clf.predict(X_test)
clf_rf.fit(X_resampled,y_resampled)

rf_pred=clf_rf.predict(X_test)

# %%
print('RF Confusion Matrix')
print(confusion_matrix(y_test, rf_pred))
print()
print("RF Classification Report")
print(classification_report(y_test, rf_pred)) 
plot_confusion_matrix(clf_rf, X_test, y_test)
# Out:
# RF Confusion Matrix
# [[96 28]
#  [35 54]]
#
# RF Classification Report
#               precision    recall  f1-score   support
#
#          0.0       0.73      0.77      0.75       124
#          1.0       0.66      0.61      0.63        89
#
#     accuracy                           0.70       213
#    macro avg       0.70      0.69      0.69       213
# weighted avg       0.70      0.70      0.70       213
# /Users/anmolsingh/opt/anaconda3/lib/python3.9/site-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function plot_confusion_matrix is deprecated; Function `plot_confusion_matrix` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: ConfusionMatrixDisplay.from_predictions or ConfusionMatrixDisplay.from_estimator.
#   warnings.warn(msg, category=FutureWarning)

# %%
# Create and train LR model
classifier = LogisticRegression(solver='lbfgs',
                                max_iter=200,
                                random_state=1)
classifier.fit(X_train, y_train)

# Execute LR predictions
predictions = classifier.predict(X_test)
results = pd.DataFrame({"Prediction": predictions, "Actual": y_test}).reset_index(drop=True)
results
# Out:
#      Prediction  Actual
# 0           0.0     0.0
# 1           1.0     1.0
# 2           0.0     0.0
# 3           0.0     0.0
# 4           1.0     0.0
# ..          ...     ...
# 208         0.0     0.0
# 209         0.0     0.0
# 210         0.0     1.0
# 211         0.0     1.0
# 212         0.0     0.0
#
# [213 rows x 2 columns]

# %%
# Create a confusion matrix
from sklearn.metrics import confusion_matrix
cf_matrix= confusion_matrix(y_test, predictions)
print(cf_matrix)
import seaborn as sns

ax = sns.heatmap(cf_matrix, annot=True, cmap='Blues')

ax.set_title('Logistic Regression Seaborn Confusion Matrix with labels\n\n');
ax.set_xlabel('\nPredicted Values')
ax.set_ylabel('Actual Values ');

# Ticket labels - List must be in alphabetical order
ax.xaxis.set_ticklabels(['False','True'])
ax.yaxis.set_ticklabels(['False','True'])
#export to image
plt.savefig("pics/logistic_regression.png",bbox_inches="tight",dpi=220)
# Display the visualization of the Confusion Matrix.
plt.show()
# Out:
# [[108  16]
#  [ 55  34]]

# %%
# Create a classification report
target_names = ["0.0", "1.0"]
print(classification_report(y_test, predictions, target_names=target_names))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.66      0.87      0.75       124
#          1.0       0.68      0.38      0.49        89
#
#     accuracy                           0.67       213
#    macro avg       0.67      0.63      0.62       213
# weighted avg       0.67      0.67      0.64       213

# %% [markdown]
# ## AdaBoost

# %%
#AdaBoost model     
from sklearn.ensemble import AdaBoostClassifier
from sklearn import metrics
from sklearn import datasets

# %%
# Create and train Adaboost model
adamodel = AdaBoostClassifier(n_estimators=50,
                         learning_rate=1)
adamodel.fit(X_train, y_train)
# Out:
# AdaBoostClassifier(learning_rate=1)

# %%
# Execute LR predictions
predictions_ada = adamodel.predict(X_test)
results_ada = pd.DataFrame({"Prediction": predictions_ada, "Actual": y_test}).reset_index(drop=True)
results_ada
# Out:
#      Prediction  Actual
# 0           0.0     0.0
# 1           1.0     1.0
# 2           1.0     0.0
# 3           0.0     0.0
# 4           1.0     0.0
# ..          ...     ...
# 208         0.0     0.0
# 209         0.0     0.0
# 210         0.0     1.0
# 211         1.0     1.0
# 212         0.0     0.0
#
# [213 rows x 2 columns]

# %%
# Create a confusion matrix
from sklearn.metrics import confusion_matrix
cf_matrix_ada= confusion_matrix(y_test, predictions_ada)
print(cf_matrix_ada)
import seaborn as sns

ax = sns.heatmap(cf_matrix_ada, annot=True, cmap='Blues')

ax.set_title('AdaBoost Seaborn Confusion Matrix with labels\n\n');
ax.set_xlabel('\nPredicted Values')
ax.set_ylabel('Actual Values ');

# Ticket labels - List must be in alphabetical order
ax.xaxis.set_ticklabels(['False','True'])
ax.yaxis.set_ticklabels(['False','True'])
#export to image
plt.savefig("pics/adaboost.png",bbox_inches="tight",dpi=220)

# Display the visualization of the Confusion Matrix.
plt.show()
# Out:
# [[99 25]
#  [40 49]]

# %%
# Create a classification report
target_names = ["0.0", "1.0"]
print(classification_report(y_test, predictions_ada, target_names=target_names))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.71      0.80      0.75       124
#          1.0       0.66      0.55      0.60        89
#
#     accuracy                           0.69       213
#    macro avg       0.69      0.67      0.68       213
# weighted avg       0.69      0.69      0.69       213

# %% [markdown]
# ## XGBoost

# %%
# Imports
import xgboost as xgb
from sklearn.metrics import mean_squared_error
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /var/folders/tb/p0ymc44s2sqb8g6stzd8f2pm0000gn/T/ipykernel_11731/3677787023.py in <module>
#       1 # Imports
# ----> 2 import xgboost as xgb
#       3 from sklearn.metrics import mean_squared_error
#
# ModuleNotFoundError: No module named 'xgboost'

# %%
#splitting of the Features and Output Variable

X, y = bz_ipo_df1.iloc[:,:-1],bz_ipo_df1.iloc[:,-1]

# %%
# convert the dataset into an optimized data structure called Dmatrix that XGBoost supports and gives it acclaimed performance and efficiency gains. 
data_dmatrix = xgb.DMatrix(X,y)

# %%
#Splitting Train and test data
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test_xg = train_test_split(X, y, test_size=0.25, random_state=69)

# %%
#Visualization Params
#xg_reg = xgb.XGBRegressor(objective ='reg:squarederror', colsample_bytree = 0.3, learning_rate = 0.1,
                #max_depth = 5, alpha = 10, n_estimators = 10)

xg_reg = xgb.XGBClassifier()

# %%
#Fit the model
xg_reg.fit(X_train,y_train)

#preds_xg = xg_reg.predict(X_test)
# Out:
# XGBClassifier(base_score=0.5, booster='gbtree', callbacks=None,
#               colsample_bylevel=1, colsample_bynode=1, colsample_bytree=1,
#               early_stopping_rounds=None, enable_categorical=False,
#               eval_metric=None, gamma=0, gpu_id=-1, grow_policy='depthwise',
#               importance_type=None, interaction_constraints='',
#               learning_rate=0.300000012, max_bin=256, max_cat_to_onehot=4,
#               max_delta_step=0, max_depth=6, max_leaves=0, min_child_weight=1,
#               missing=nan, monotone_constraints='()', n_estimators=100,
#               n_jobs=0, num_parallel_tree=1, predictor='auto', random_state=0,
#               reg_alpha=0, reg_lambda=1, ...)

# %%
# Execute LR predictions
preds_xg = xg_reg.predict(X_test)

# %%
results_xg = pd.DataFrame({"Prediction": preds_xg, "Actual": y_test_xg}).reset_index(drop=True)
results_xg
# Out:
#      Prediction  Actual
# 0             0     0.0
# 1             1     1.0
# 2             1     0.0
# 3             0     0.0
# 4             1     0.0
# ..          ...     ...
# 208           0     0.0
# 209           0     0.0
# 210           0     1.0
# 211           1     1.0
# 212           0     0.0
#
# [213 rows x 2 columns]

# %%
rmse = np.sqrt(mean_squared_error(y_test_xg, preds_xg))
print("RMSE: %f" % (rmse))
# Out:
# RMSE: 0.548151

# %%
#k-fold Cross Validation using XGBoost. In order to build more robust models, it is common to do a k-fold cross validation 
# where all the entries in the original training dataset are used for both training as well as validation. 
# Also, each entry is used for validation just once.
params = {"objective":"reg:squarederror",'colsample_bytree': 0.3,'learning_rate': 0.1,
                'max_depth': 5, 'alpha': 10}

cv_results = xgb.cv(dtrain=data_dmatrix, params=params, nfold=3,
                    num_boost_round=50,early_stopping_rounds=10,metrics="rmse", as_pandas=True, seed=69)

# %%
#Visualize Boosting Trees and Feature Importance
xg_reg = xgb.train(params=params, dtrain=data_dmatrix, num_boost_round=10)

# %%
# Plotting the first tree with the matplotlib library
import matplotlib.pyplot as plt

xgb.plot_tree(xg_reg,num_trees=0)
plt.rcParams['figure.figsize'] = [10, 10]
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-173-16d2d88666fe> in <module>
#       2 import matplotlib.pyplot as plt
#       3
# ----> 4 xgb.plot_tree(xg_reg,num_trees=0)
#       5 plt.rcParams['figure.figsize'] = [10, 10]
#       6 plt.show()
#
# ~\Documents\Bootcamp\envs\dev\lib\site-packages\xgboost\plotting.py in plot_tree(booster, fmap, num_trees, rankdir, ax, **kwargs)
#     246
#     247     g = to_graphviz(booster, fmap=fmap, num_trees=num_trees, rankdir=rankdir,
# --> 248                     **kwargs)
#     249
#     250     s = BytesIO()
#
# ~\Documents\Bootcamp\envs\dev\lib\site-packages\xgboost\plotting.py in to_graphviz(booster, fmap, num_trees, rankdir, yes_color, no_color, condition_node_params, leaf_node_params, **kwargs)
#     169     """
#     170     try:
# --> 171         from graphviz import Source
#     172     except ImportError as e:
#     173         raise ImportError('You must install graphviz to plot tree') from e
#
# ~\Documents\Bootcamp\envs\dev\lib\site-packages\graphviz\__init__.py in <module>
#      25 """
#      26
# ---> 27 from .dot import Graph, Digraph
#      28 from .files import Source
#      29 from .lang import escape, nohtml
#
# ~\Documents\Bootcamp\envs\dev\lib\site-packages\graphviz\dot.py in <module>
#      30
#      31 from . import backend
# ---> 32 from . import files
#      33 from . import lang
#      34
#
# ~\Documents\Bootcamp\envs\dev\lib\site-packages\graphviz\files.py in <module>
#      20
#      21
# ---> 22 class Base(object):
#      23
#      24     _engine = 'dot'
#
# ~\Documents\Bootcamp\envs\dev\lib\site-packages\graphviz\files.py in Base()
#      26     _format = 'pdf'
#      27
# ---> 28     _encoding = backend.ENCODING
#      29
#      30     @property
#
# AttributeError: module 'graphviz.backend' has no attribute 'ENCODING'

# %%
# Visualizing the feature importance result as a bar graph
xgb.plot_importance(xg_reg)
plt.rcParams['figure.figsize'] = [15, 15]
plt.show()

# %%
# Confusion matrix
cf_matrix_xg= confusion_matrix(y_test_xg, preds_xg)
print(cf_matrix_xg)
# Out:
# [[97 27]
#  [37 52]]

# %%
# Create a classification report
target_names = ["0.0", "1.0"]
print(classification_report(y_test_xg, preds_xg, target_names=target_names))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.72      0.78      0.75       124
#          1.0       0.66      0.58      0.62        89
#
#     accuracy                           0.70       213
#    macro avg       0.69      0.68      0.69       213
# weighted avg       0.70      0.70      0.70       213

# %%
# Create a confusion matrix
from sklearn.metrics import confusion_matrix
cf_matrix_xg= confusion_matrix(y_test_xg, preds_xg)
print(cf_matrix_xg)
import seaborn as sns

ax = sns.heatmap(cf_matrix_xg, annot=True, cmap='Blues')

ax.set_title('AdaBoost Seaborn Confusion Matrix with labels\n\n')
ax.set_xlabel('\nPredicted Values')
ax.set_ylabel('Actual Values ')

# Ticket labels - List must be in alphabetical order
ax.xaxis.set_ticklabels(['False','True'])
ax.yaxis.set_ticklabels(['False','True'])
#export to image
plt.savefig("pics/xgboost.png",dpi=220)

# Display the visualization of the Confusion Matrix.
plt.show()
# Out:
# [[97 27]
#  [37 52]]
